# %%
## Graphdb configuration
#NEO4J_URI="neo4j+s://b7a6eb28.databases.neo4j.io"
NEO4J_URI="neo4j+s://b7a6eb28.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="-l0_XZ27zrICNl4ynPtYISuXlQS28oFQKVjGF8agvkH4"

# %%
import os
os.environ["NEO4J_URI"]=NEO4J_URI
os.environ["NEO4J_USERNAME"]=NEO4J_USERNAME
os.environ["NEO4J_PASSWORD"]=NEO4J_PASSWORD

# %%
from langchain_community.graphs import Neo4jGraph
graph=Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py:415, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     414 try:
# --> 415     self._driver.verify_connectivity()
#     416 except neo4j.exceptions.ServiceUnavailable:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/driver.py:1064, in Driver.verify_connectivity(self, **config)
#    1063 session_config = self._read_session_config(config)
# -> 1064 self._get_server_info(session_config)
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/driver.py:1293, in Driver._get_server_info(self, session_config)
#    1292 with self._session(session_config) as session:
# -> 1293     return session._get_server_info()
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/work/session.py:175, in Session._get_server_info(self)
#     174 assert not self._connection
# --> 175 self._connect(
#     176     READ_ACCESS, liveness_check_timeout=0, unprepared=True
#     177 )
#     178 server_info = self._connection.server_info
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/work/session.py:128, in Session._connect(self, access_mode, **acquire_kwargs)
#     127 try:
# --> 128     super()._connect(
#     129         access_mode, auth=self._config.auth, **acquire_kwargs
#     130     )
#     131 except asyncio.CancelledError:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:166, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     165 ssr_enabled = self._pool.ssr_enabled
# --> 166 target_db = self._get_routing_target_database(
#     167     acquire_auth,
#     168     ssr_enabled=ssr_enabled,
#     169     acquisition_deadline=acquisition_deadline,
#     170 )
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:244, in Workspace._get_routing_target_database(self, acquire_auth, ssr_enabled, acquisition_deadline)
#     243 log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 244 self._pool.update_routing_table(
#     245     database=self._config.database,
#     246     imp_user=self._config.impersonated_user,
#     247     bookmarks=self._get_bookmarks(),
#     248     auth=acquire_auth,
#     249     acquisition_timeout=acquisition_deadline,
#     250     database_callback=self._make_db_resolution_callback(),
#     251 )
#     252 return AcquisitionDatabase(self._config.database)
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:1009, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#    1003     prefer_initial_routing_address = True
#    1005 if (
#    1006     prefer_initial_routing_address
#    1007     and
#    1008     # TODO: Test this state
# -> 1009     self._update_routing_table_from(
#    1010         self.address,
#    1011         database=database,
#    1012         imp_user=imp_user,
#    1013         bookmarks=bookmarks,
#    1014         auth=auth,
#    1015         acquisition_timeout=acquisition_timeout,
#    1016         database_callback=database_callback,
#    1017         ignored_errors=errors,
#    1018     )
#    1019 ):
#    1020     # Why is only the first initial routing address used?
#    1021     return
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:935, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, ignored_errors, *routers)
#     932 for address in NetworkUtil.resolve_address(
#     933     router, resolver=self.pool_config.resolver
#     934 ):
# --> 935     new_routing_table = self.fetch_routing_table(
#     936         address=address,
#     937         acquisition_timeout=acquisition_timeout,
#     938         database=database,
#     939         imp_user=imp_user,
#     940         bookmarks=bookmarks,
#     941         auth=auth,
#     942         ignored_errors=ignored_errors,
#     943     )
#     944     if new_routing_table is not None:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:833, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth, ignored_errors)
#     832 try:
# --> 833     new_routing_info = self.fetch_routing_info(
#     834         address,
#     835         database,
#     836         imp_user,
#     837         bookmarks,
#     838         auth,
#     839         acquisition_timeout,
#     840     )
#     841 except Neo4jError as e:
#     842     # checks if the code is an error that is caused by the client. In
#     843     # this case there is no sense in trying to fetch a RT from another
#     844     # router. Hence, the driver should fail fast during discovery.
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:792, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     791     auth.force_auth = False
# --> 792 cx = self._acquire(address, auth, deadline, None)
#     793 try:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     230 try:
# --> 231     connection = self.opener(
#     232         address, auth or self.pool_config.auth, deadline
#     233     )
#     234 except ServiceUnavailable:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:711, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     710 def opener(addr, auth_manager, deadline):
# --> 711     return Bolt.open(
#     712         addr,
#     713         auth_manager=auth_manager,
#     714         deadline=deadline,
#     715         routing_context=routing_context,
#     716         pool_config=pool_config,
#     717     )
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:426, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     425 try:
# --> 426     connection.hello()
#     427 finally:
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_bolt6.py:185, in Bolt6x0.hello(self, dehydration_hooks, hydration_hooks)
#     184 self.send_all()
# --> 185 self.fetch_all()
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:883, in Bolt.fetch_all(self)
#     882 while not response.complete:
# --> 883     detail_delta, summary_delta = self.fetch_message()
#     884     detail_count += detail_delta
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:868, in Bolt.fetch_message(self)
#     865 tag, fields = self.inbox.pop(
#     866     hydration_hooks=self.responses[0].hydration_hooks
#     867 )
# --> 868 res = self._process_message(tag, fields)
#     869 self.idle_since = monotonic()
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_bolt6.py:548, in Bolt6x0._process_message(self, tag, fields)
#     547 try:
# --> 548     response.on_failure(summary_metadata or {})
#     549 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/neo4j/_sync/io/_common.py:304, in LogonResponse.on_failure(self, metadata)
#     303 Util.callback(handler)
# --> 304 raise self._hydrate_error(metadata)
#
# AuthError: {neo4j_code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.} {gql_status: 42NFF} {gql_status_description: error: syntax error or access rule violation - permission/access denied. Access denied, see the security logs for details.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 2 graph=Neo4jGraph(
#       3     url=NEO4J_URI,
#       4     username=NEO4J_USERNAME,
#       5     password=NEO4J_PASSWORD,
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:237, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     235     warned = True
#     236     emit_warning()
# --> 237 return wrapped(self, *args, **kwargs)
#
# File ~/miniforge3/envs/nlp-genai/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py:422, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     417     raise ValueError(
#     418         "Could not connect to Neo4j database. "
#     419         "Please ensure that the url is correct"
#     420     )
#     421 except neo4j.exceptions.AuthError:
# --> 422     raise ValueError(
#     423         "Could not connect to Neo4j database. "
#     424         "Please ensure that the username and password are correct"
#     425     )
#     426 # Set schema
#     427 if refresh_schema:
#
# ValueError: Could not connect to Neo4j database. Please ensure that the username and password are correct

# %%
groq_api_key= "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"

# %%
from langchain_groq import ChatGroq

llm=ChatGroq(groq_api_key=groq_api_key,model_name="llama-3.1-8b-instant")
llm
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x3206ac590>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x3206b9a00>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from langchain_core.documents import Document
text="""
Elon Reeve Musk (born June 28, 1971) is a businessman and investor known for his key roles in space
company SpaceX and automotive company Tesla, Inc. Other involvements include ownership of X Corp.,
formerly Twitter, and his role in the founding of The Boring Company, xAI, Neuralink and OpenAI.
He is one of the wealthiest people in the world; as of July 2024, Forbes estimates his net worth to be
US$221 billion.Musk was born in Pretoria to Maye and engineer Errol Musk, and briefly attended
the University of Pretoria before immigrating to Canada at age 18, acquiring citizenship through
his Canadian-born mother. Two years later, he matriculated at Queen's University at Kingston in Canada.
Musk later transferred to the University of Pennsylvania and received bachelor's degrees in economics
 and physics. He moved to California in 1995 to attend Stanford University, but dropped out after
  two days and, with his brother Kimbal, co-founded online city guide software company Zip2.
 """
documents=[Document(page_content=text)]
documents
# Out:
# [Document(metadata={}, page_content="\nElon Reeve Musk (born June 28, 1971) is a businessman and investor known for his key roles in space\ncompany SpaceX and automotive company Tesla, Inc. Other involvements include ownership of X Corp.,\nformerly Twitter, and his role in the founding of The Boring Company, xAI, Neuralink and OpenAI.\nHe is one of the wealthiest people in the world; as of July 2024, Forbes estimates his net worth to be\nUS$221 billion.Musk was born in Pretoria to Maye and engineer Errol Musk, and briefly attended\nthe University of Pretoria before immigrating to Canada at age 18, acquiring citizenship through\nhis Canadian-born mother. Two years later, he matriculated at Queen's University at Kingston in Canada.\nMusk later transferred to the University of Pennsylvania and received bachelor's degrees in economics\n and physics. He moved to California in 1995 to attend Stanford University, but dropped out after\n  two days and, with his brother Kimbal, co-founded online city guide software company Zip2.\n ")]

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer=LLMGraphTransformer(llm=llm)

# %%
graph_documents=llm_transformer.convert_to_graph_documents(documents)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Elon Musk', type='Person', properties={}), Node(id='Spacex', type='Company', properties={}), Node(id='Tesla, Inc.', type='Company', properties={}), Node(id='X Corp.', type='Company', properties={}), Node(id='Twitter', type='Company', properties={}), Node(id='The Boring Company', type='Company', properties={}), Node(id='Xai', type='Company', properties={}), Node(id='Neuralink', type='Company', properties={}), Node(id='Openai', type='Company', properties={}), Node(id='Maye', type='Person', properties={}), Node(id='Errol Musk', type='Person', properties={}), Node(id='Kimbal Musk', type='Person', properties={}), Node(id='Pretoria', type='Place', properties={}), Node(id='University Of Pretoria', type='Institution', properties={}), Node(id='Canada', type='Place', properties={}), Node(id="Queen'S University At Kingston", type='Institution', properties={}), Node(id='University Of Pennsylvania', type='Institution', properties={}), Node(id='Stanford University', type='Institution', properties={}), Node(id='California', type='Place', properties={}), Node(id='Zip2', type='Company', properties={})], relationships=[Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Spacex', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Tesla, Inc.', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='X Corp.', type='Company', properties={}), type='OWNER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Twitter', type='Company', properties={}), type='OWNER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='The Boring Company', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Xai', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Neuralink', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Openai', type='Company', properties={}), type='FOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Zip2', type='Company', properties={}), type='COFOUNDER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='University Of Pretoria', type='Institution', properties={}), type='ALUMNUS', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id="Queen'S University At Kingston", type='Institution', properties={}), type='ALUMNUS', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='University Of Pennsylvania', type='Institution', properties={}), type='ALUMNUS', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Stanford University', type='Institution', properties={}), type='ATTENDED', properties={}), Relationship(source=Node(id='Maye', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='PARENT', properties={}), Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='PARENT', properties={}), Relationship(source=Node(id='Kimbal Musk', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='BROTHER', properties={}), Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Pretoria', type='Place', properties={}), type='BORN', properties={}), Relations ...

# %%
graph_documents[0].nodes
# Out:
# [Node(id='Elon Musk', type='Person', properties={}),
#  Node(id='Spacex', type='Company', properties={}),
#  Node(id='Tesla, Inc.', type='Company', properties={}),
#  Node(id='X Corp.', type='Company', properties={}),
#  Node(id='Twitter', type='Company', properties={}),
#  Node(id='The Boring Company', type='Company', properties={}),
#  Node(id='Xai', type='Company', properties={}),
#  Node(id='Neuralink', type='Company', properties={}),
#  Node(id='Openai', type='Company', properties={}),
#  Node(id='Maye', type='Person', properties={}),
#  Node(id='Errol Musk', type='Person', properties={}),
#  Node(id='Kimbal Musk', type='Person', properties={}),
#  Node(id='Pretoria', type='Place', properties={}),
#  Node(id='University Of Pretoria', type='Institution', properties={}),
#  Node(id='Canada', type='Place', properties={}),
#  Node(id="Queen'S University At Kingston", type='Institution', properties={}),
#  Node(id='University Of Pennsylvania', type='Institution', properties={}),
#  Node(id='Stanford University', type='Institution', properties={}),
#  Node(id='California', type='Place', properties={}),
#  Node(id='Zip2', type='Company', properties={})]

# %%
graph_documents[0].relationships
# Out:
# [Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Spacex', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Tesla, Inc.', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='X Corp.', type='Company', properties={}), type='OWNER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Twitter', type='Company', properties={}), type='OWNER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='The Boring Company', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Xai', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Neuralink', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Openai', type='Company', properties={}), type='FOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Zip2', type='Company', properties={}), type='COFOUNDER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='University Of Pretoria', type='Institution', properties={}), type='ALUMNUS', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id="Queen'S University At Kingston", type='Institution', properties={}), type='ALUMNUS', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='University Of Pennsylvania', type='Institution', properties={}), type='ALUMNUS', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Stanford University', type='Institution', properties={}), type='ATTENDED', properties={}),
#  Relationship(source=Node(id='Maye', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='PARENT', properties={}),
#  Relationship(source=Node(id='Errol Musk', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='PARENT', properties={}),
#  Relationship(source=Node(id='Kimbal Musk', type='Person', properties={}), target=Node(id='Elon Musk', type='Person', properties={}), type='BROTHER', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Pretoria', type='Place', properties={}), type='BORN', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='Canada', type='Place', properties={}), type='IMMIGRATED_TO', properties={}),
#  Relationship(source=Node(id='Elon Musk', type='Person', properties={}), target=Node(id='California', type='Place', properties={}), type='RESIDED_IN', properties={})]

# %%
### Load the dataset of movie

movie_query="""
LOAD CSV WITH HEADERS FROM
'https://raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv' as row

MERGE(m:Movie{id:row.movieId})
SET m.released = date(row.released),
    m.title = row.title,
    m.imdbRating = toFloat(row.imdbRating)
FOREACH (director in split(row.director, '|') |
    MERGE (p:Person {name:trim(director)})
    MERGE (p)-[:DIRECTED]->(m))
FOREACH (actor in split(row.actors, '|') |
    MERGE (p:Person {name:trim(actor)})
    MERGE (p)-[:ACTED_IN]->(m))
FOREACH (genre in split(row.genres, '|') |
    MERGE (g:Genre {name:trim(genre)})
    MERGE (m)-[:IN_GENRE]->(g))
"""

# %%
graph
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 graph
#
# NameError: name 'graph' is not defined

# %%
graph.query(movie_query)

# %%
graph.refresh_schema()
print(graph.schema)

# %%
from langchain.chains import GraphCypherQAChain
chain=GraphCypherQAChain.from_llm(llm=llm,graph=graph,verbose=True)
chain

# %%
response=chain.invoke({"query":"Who was the director of the moview GoldenEye"})

response

# %%
response=chain.invoke({"query":"tell me the genre of th movie GoldenEye"})

response
